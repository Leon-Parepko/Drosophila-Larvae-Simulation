# %%
import os
os.chdir("../../../..")

# %%
import scripts.data_to_jax as dj

# %%
out_dir = 'Datasets/Generated/jax/2025d5/'
in_dir = 'Datasets/Generated/gml/'
paths = [
    "test_graph_20n",
    "complete_graph(3k)",
]

for p in paths:
    print(f"processing {p}.gml")
    dj.process_basic(os.path.join(in_dir, f"{p}.gml"), os.path.join(out_dir, f"{p}.npz"))
# Out:
# processing test_graph_20n.gml
# Начало обработки графа (маппинги и ребра)...
# Обработка завершена. Найдено 2 групп и 3 массивов ребер.
# Начало сохранения данных в Datasets/Generated/jax/2025d5/test_graph_20n.npz...
# Сохранение завершено. Всего 7 массивов (ребер + дополнительных) и метаданные сохранены.
# processing complete_graph(3k).gml
# Начало обработки графа (маппинги и ребра)...
# Обработка завершена. Найдено 2 групп и 3 массивов ребер.
# Начало сохранения данных в Datasets/Generated/jax/2025d5/complete_graph(3k).npz...
# Сохранение завершено. Всего 7 массивов (ребер + дополнительных) и метаданные сохранены.
