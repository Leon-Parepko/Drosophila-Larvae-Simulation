# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.use('dark_background')

# %%
def get_diff_matrix(data_prev, data_next, weights = 1):
    a = np.stack([data_prev]*len(data_next), 0)
    b = np.stack([data_next]*len(data_prev), 0)
    axies = [i for i in range(len(b.shape))]
    axies[0], axies[1] = axies[1], axies[0]
    b = np.transpose(b, axies)
    return (a - b)*weights

def add_axi(a):
    return np.reshape(a, [*a.shape, 1])

# %%
activity = pd.read_csv('./a_medium_one.csv', index_col=0).to_numpy()

# %%
activity.shape
# Out:
# (10001, 50)

# %%
plt.imshow(activity)
plt.show()

# %%
dot_products = activity @ activity.T
#dot_products = dot_products# - np.min(dot_products)
#plt.imshow(np.log10(dot_products + 0.00000001))
plt.imshow(dot_products)
plt.colorbar()
plt.show()
